# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
m=pd.read_csv("Desktop\m.csv")

# %%
m.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
m1 = m.fillna(0)

# %%
m1.isnull().sum()
# Out:
# id                      0
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# homepage                0
# director                0
# tagline                 0
# keywords                0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %%
m1.duplicated().sum()
# Out:
# 1

# %%
m1.drop_duplicates(inplace=True)

# %%
m1.drop(['imdb_id','homepage','tagline','overview','budget_adj','revenue_adj','keywords'], axis=1, inplace = True)

# %%
m1['release_date'] = pd.to_datetime(m1['release_date'])

# %%
m1['release_date'].head(2)
# Out:
# 0   2015-06-09
# 1   2015-05-13
# Name: release_date, dtype: datetime64[ns]

# %%
year_data =m1.groupby('release_year').count()['id']

# %%
year_data.plot.line()
plt.ylabel('Count')
sns.set_style("whitegrid");

# %%
column = m1['revenue']
max_revenue = column.max()
m1.loc[m1['revenue'] == max_revenue]
# Out:
#          id  popularity     budget     revenue original_title  \
# 1386  19995    9.432768  237000000  2781505847         Avatar
#
#                                                    cast       director  \
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#       runtime                                    genres  \
# 1386      162  Action|Adventure|Fantasy|Science Fiction
#
#                                    production_companies release_date  \
# 1386  Ingenious Film Partners|Twentieth Century Fox ...   2009-12-10
#
#       vote_count  vote_average  release_year
# 1386        8458           7.1          2009

# %%
column = m1['revenue']
min_revenue = column.min()
m1.loc[m1['revenue'] == min_revenue]
# Out:
#            id  popularity    budget  revenue                  original_title  \
# 48     265208    2.932340  30000000        0                       Wild Card
# 67     334074    2.331636  20000000        0                        Survivor
# 74     347096    2.165433         0        0          Mythica: The Darkspore
# 75     308369    2.141506         0        0  Me and Earl and the Dying Girl
# 92     370687    1.876037         0        0        Mythica: The Necromancer
# ...       ...         ...       ...      ...                             ...
# 10861      21    0.080598         0        0              The Endless Summer
# 10862   20379    0.065543         0        0                      Grand Prix
# 10863   39768    0.065141         0        0             Beregis Avtomobilya
# 10864   21449    0.064317         0        0          What's Up, Tiger Lily?
# 10865   22293    0.035919     19000        0        Manos: The Hands of Fate
#
# ...

# %%
sns.regplot(x=m1['popularity'],y=m1['revenue'],color='c');
revenue_corr = m1.corr()

print("Correlation Between Popularity And revenue : ",revenue_corr.loc['popularity','revenue'])
# Out:
# Correlation Between Popularity And revenue :  0.663360281412586

# %%
sns.regplot(x=m1['popularity'],y=m1['budget'],color='c');
budget_corr = m1.corr()

print("Correlation Between Popularity and Budget : ",budget_corr.loc['popularity','budget'])
# Out:
# Correlation Between Popularity and Budget :  0.5454807929309621

# %%
m1.groupby('runtime')['popularity'].mean().plot(figsize = (13,5));
plt.xlabel('runtime')
plt.ylabel('popularity')

sns.set_style("whitegrid");

# %%
sns.regplot(x=m1['popularity'],y=m1['runtime'],color='c');
runtime_corr = m1.corr()

print("Correlation Between Popularity and Runtime : ",runtime_corr.loc['popularity','runtime'])
# Out:
# Correlation Between Popularity and Runtime :  0.13903177277430356

# %%
def film_counter(x):
    #concatenate all the rows of the genres.
    data_plot = m[x].str.cat(sep = '|')
    data = pd.Series(data_plot.split('|'))
    #conts each of the genre and return.
    info = data.value_counts(ascending=False)
    return info

# %%
total_genres = film_counter('genres')
print(total_genres)
# Out:
# Drama              4761
# Comedy             3793
# Thriller           2908
# Action             2385
# Romance            1712
# Horror             1637
# Adventure          1471
# Crime              1355
# Family             1231
# Science Fiction    1230
# Fantasy             916
# Mystery             810
# Animation           699
# Documentary         520
# Music               408
# History             334
# War                 270
# Foreign             188
# TV Movie            167
# Western             165
# dtype: int64

# %%
total_genres.plot.bar(figsize =(15,15), fontsize = 12)
plt.xlabel('Genres')
plt.ylabel('Number of films')
sns.set_context('paper')

# %%
total_genres.plot.pie(figsize =(15,15), fontsize = 15, autopct='%.1f%%');

# %%
r = m1.groupby('budget').count()['revenue']

# %%
m1.tail(5)
# Out:
#           id  popularity  budget  revenue            original_title  \
# 10861     21    0.080598       0        0        The Endless Summer
# 10862  20379    0.065543       0        0                Grand Prix
# 10863  39768    0.065141       0        0       Beregis Avtomobilya
# 10864  21449    0.064317       0        0    What's Up, Tiger Lily?
# 10865  22293    0.035919   19000        0  Manos: The Hands of Fate
#
#                                                     cast            director  \
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...         Bruce Brown
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...  John Frankenheimer
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      Eldar Ryazanov
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...         Woody Allen
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...    Harold P. Warren
#
#        runtime                  genres  \
# 10861       95             Documentary
# ...
